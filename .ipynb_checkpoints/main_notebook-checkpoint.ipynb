# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
import requests
import json
import pandas as pd

# %%
import getpass
apikey = getpass.getpass()
# Out:
# ········

# %%
# The first API

# %%
response = requests.get('http://makeup-api.herokuapp.com/api/v1/products.json')

# %%
results = response.json()
#results

# %%
data = pd.DataFrame(response.json())
data.head()
# Out:
#      id      brand                  name price price_sign currency  \
# 0  1048  colourpop         Lippie Pencil   5.0          $      CAD
# 1  1047  colourpop           Blotted Lip   5.5          $      CAD
# 2  1046  colourpop           Lippie Stix   5.5          $      CAD
# 3  1045  colourpop  No Filter Foundation  12.0          $      CAD
# 4  1044      boosh              Lipstick  26.0          $      CAD
#
#                                           image_link  \
# 0  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 2  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 3  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 4  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                         product_link  \
# 0    https://colourpop.com/collections/lippie-pencil
# 1  https://colourpop.com/collections/lippie-stix?...
# 2      https://colourpop.com/collections/lippie-stix
# ...

# %%
from pandas.io.json import json_normalize

# %%
flattened_data = json_normalize(results)

flattened_data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7180\2141200709.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(results)
#                                             networks
# 0  [{'company': ['ЗАО «СитиБайк»'], 'href': '/v2/...

# %%
#flattened_data=flattened_data.drop('product_colors',axis=1)

# %%
flattened_data.head()

# %%
# using this dataset  we can compare the prices of products of the same type of different brand.

# %%
# The second API

# %%
response = requests.get('http://api.citybik.es/v2/networks')

# %%
results = response.json()
#results

# %%
data = pd.DataFrame(response.json())
data1=data['networks']

# %%
flattened_data = json_normalize(data1)

flattened_data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7180\289793336.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(data1)
#                             company                               href  \
# 0                  [ЗАО «СитиБайк»]       /v2/networks/velobike-moscow
# 1                      [Gobike A/S]              /v2/networks/bycyklen
# 2                      [Gobike A/S]            /v2/networks/nu-connect
# 3    [Urban Infrastructure Partner]       /v2/networks/baerum-bysykkel
# 4                      [Gobike A/S]            /v2/networks/bysykkelen
# ..                              ...                                ...
# 652                 [Nextbike GmbH]             /v2/networks/winsenrad
# 653                 [Nextbike GmbH]           /v2/networks/loker-lomza
# 654                 [Nextbike GmbH]  /v2/networks/nomago-kranjska-gora
# ...

# %%
# According to this dataset, we can get information about the bikes of each company

# %%
# The third API

# %%
response=requests.get('https://opentdb.com/api.php?amount=50')

# %%
results = response.json()
#results

# %%
data = pd.DataFrame(response.json())
data1=data['results']

# %%
flattened_data=json_normalize(data1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7180\4207282761.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data=json_normalize(data1)

# %%
flattened_data
# Out:
#                                  category      type difficulty  \
# 0                       General Knowledge  multiple       hard
# 1                               Geography  multiple     medium
# 2                       General Knowledge  multiple     medium
# 3                      Science: Computers   boolean     medium
# 4                      Science: Computers  multiple       easy
# 5                     Entertainment: Film  multiple     medium
# 6                               Geography  multiple     medium
# 7                                Vehicles  multiple     medium
# 8                               Geography  multiple       hard
# 9                    Entertainment: Music  multiple     medium
# 10              Entertainment: Television  multiple     medium
# 11    Entertainment: Cartoon & Animations  multiple     medium
# 12  Entertainment: Japanese Anime & Manga  multiple       hard
# 13                      General Knowledge   boolean     medium
# ...

# %%
response=requests.get('https://api.domainsdb.info/v1/domains/search?domain=facebook')

# %%
results = response.json()
#results

# %%
data = pd.DataFrame(response.json())
data.head()
# Out:
#                                              domains  total time next_page
# 0  {'domain': 'facebook-cover.net', 'create_date'...    220  453      None
# 1  {'domain': 'facebook-services.net', 'create_da...    220  453      None
# 2  {'domain': 'facebook-italia.net', 'create_date...    220  453      None
# 3  {'domain': 'facebook-meta.net', 'create_date':...    220  453      None
# 4  {'domain': 'facebook-security.net', 'create_da...    220  453      None

# %%
data1=data['domains']

# %%
flattened_data=json_normalize(data1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7180\4207282761.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data=json_normalize(data1)

# %%
flattened_data
# Out:
#                               domain                 create_date  \
# 0                 facebook-cover.net  2022-10-02T06:03:28.142419
# 1              facebook-services.net  2022-09-27T05:58:32.501555
# 2                facebook-italia.net  2022-09-22T18:31:10.749028
# 3                  facebook-meta.net  2022-09-22T18:31:10.749212
# 4              facebook-security.net  2022-09-22T18:31:10.749416
# 5   facebook-support-coronavirus.net  2022-09-22T18:31:10.749604
# 6        facebook-supportcovid19.net  2022-09-22T18:31:10.749802
# 7                  facebook-help.net  2022-09-22T18:31:10.748107
# 8     facebook-information-covid.net  2022-09-22T18:31:10.748286
# 9   facebook-information-covid19.net  2022-09-22T18:31:10.748465
# 10  facebook-informationcovid-19.net  2022-09-22T18:31:10.748643
# 11     facebook-informationcovid.net  2022-09-22T18:31:10.748844
# 12     facebook-covid-19-support.net  2022-09-22T18:31:10.747047
# ...

# %%
response=requests.get('https://api.domainsdb.info/v1/domains/search?domain=facebook')

# %%
results = response.json()
results
# Out:
# {'domains': [{'domain': 'facebook-cover.net',
#    'create_date': '2022-10-02T06:03:28.142419',
#    'update_date': '2022-10-02T06:03:28.142422',
#    'country': 'IE',
#    'isDead': 'False',
#    'A': ['52.17.250.95'],
#    'NS': ['ns3.systemdns.com', 'ns1.systemdns.com', 'ns2.systemdns.com'],
#    'CNAME': None,
#    'MX': [{'exchange': 'mx.facebook-cover.net.cust.a.hostedemail.com',
#      'priority': 10}],
#    'TXT': None},
#   {'domain': 'facebook-services.net',
#    'create_date': '2022-09-27T05:58:32.501555',
#    'update_date': '2022-09-27T05:58:32.501558',
#    'country': 'CA',
#    'isDead': 'False',
#    'A': ['23.227.38.73'],
#    'NS': ['ns-cloud-d3.googledomains.com',
#     'ns-cloud-d2.googledomains.com',
#     'ns-cloud-d1.googledomains.com',
#     'ns-cloud-d4.googledomains.com'],
#    'CNAME': None,
#    'MX': [{'exchange': 'mx.facebook-services.net.cust.b.hostedemail.com',
#      'priority': 1}],
#    'TXT': None},
#   {'domain': 'facebook-italia.net',
# ...

# %%
flattened_data=json_normalize(results)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7180\4124758775.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data=json_normalize(results)

# %%
flattened_data
# Out:
#                                              domains  total time next_page
# 0  [{'domain': 'facebook-cover.net', 'create_date...    220  550      None

# %%
data1=flattened_data['domains']

# %%
flattened_1=json_normalize(data1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7180\3950545510.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_1=json_normalize(data1)

# %%
flattened_1
# Out:
#                                                   0   \
# 0  {'domain': 'facebook-cover.net', 'create_date'...
#
#                                                   1   \
# 0  {'domain': 'facebook-services.net', 'create_da...
#
#                                                   2   \
# 0  {'domain': 'facebook-italia.net', 'create_date...
#
#                                                   3   \
# 0  {'domain': 'facebook-meta.net', 'create_date':...
#
#                                                   4   \
# 0  {'domain': 'facebook-security.net', 'create_da...
#
#                                                   5   \
# 0  {'domain': 'facebook-support-coronavirus.net',...
#
#                                                   6   \
# 0  {'domain': 'facebook-supportcovid19.net', 'cre...
#
#                                                   7   \
# 0  {'domain': 'facebook-help.net', 'create_date':...
#
#                                                   8   \
# ...

# %%
# I feel a little confused about this case. First of all in this case i find that there are a lot of dictionaries in 'domains' column.
# So i set new variable data1 which equals data['domains'] and then i flatten the data1 using json_normalize and it works successfully.
# The second time i try to flatten this data at first and i get the flattened data. I set data1 equals flattened_data['domains'] and then i flatten data1. 
# But as you see i fail this time. I can't get the dataframe. I want to know why this happens.
